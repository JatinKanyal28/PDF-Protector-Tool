# %%
# Music player in python

from pygame import mixer

mixer.init()
# --------------------------Path of your music
mixer.music.load("Gulabo.mp3")
mixer.music.set_volume(0.5)
mixer.music.play()

while True:
    print("Press 'p' to pause")
    print("Press 'r' to resume")
    print("Press 'v' set volume")
    print("Press 'e' to exit")

    ch = input("['p','r','v','e']>>>")

    if ch == "p":
        mixer.music.pause()
    elif ch == "r":
        mixer.music.unpause()
    elif ch == "v":
        v = float(input("Enter volume(0 to 1): "))
        mixer.music.set_volume(v)
    elif ch == "e":
        mixer.music.stop()
        break

# Follow @code_snail
# Out:
# Press 'p' to pause
# Press 'r' to resume
# Press 'v' set volume
# Press 'e' to exit
# ['p','r','v','e']>>>p
# Press 'p' to pause
# Press 'r' to resume
# Press 'v' set volume
# Press 'e' to exit
# ['p','r','v','e']>>>r
# Press 'p' to pause
# Press 'r' to resume
# Press 'v' set volume
# Press 'e' to exit
# ['p','r','v','e']>>>e

# %% [markdown]
# ## list of songs

# %%
from pygame import mixer

def play_song(song_list, index):
    mixer.music.load(song_list[index])
    mixer.music.play()

def main():
    mixer.init()

    song_list = ["Gulabo.mp3", "Anveshna.mp3", "IkKudi.mp3","Maharani.mp3"]  # Add your song filenames here
    current_song_index = 0
    play_song(song_list, current_song_index)

    while True:
        print("Press 'p' to pause")
        print("Press 'r' to resume")
        print("Press 'n' for next song")
        print("Press 'p' for previous song")
        print("Press 'v' to set volume")
        print("Press 'e' to exit")

        ch = input(">>> ")

        if ch == "p":
            mixer.music.pause()
        elif ch == "r":
            mixer.music.unpause()
        elif ch == "n":
            current_song_index = (current_song_index + 1) % len(song_list)
            mixer.music.stop()
            play_song(song_list, current_song_index)
        elif ch == "b":
            current_song_index = (current_song_index - 1) % len(song_list)
            mixer.music.stop()
            play_song(song_list, current_song_index)
        elif ch == "v":
            v = float(input("Enter volume (0 to 1): "))
            mixer.music.set_volume(v)
        elif ch == "e":
            mixer.music.stop()
            break

    mixer.quit()

if __name__ == "__main__":
    main()
# Out:
# Press 'p' to pause
# Press 'r' to resume
# Press 'n' for next song
# Press 'p' for previous song
# Press 'v' to set volume
# Press 'e' to exit
# >>> p
# Press 'p' to pause
# Press 'r' to resume
# Press 'n' for next song
# Press 'p' for previous song
# Press 'v' to set volume
# Press 'e' to exit
# >>> p
# Press 'p' to pause
# Press 'r' to resume
# Press 'n' for next song
# Press 'p' for previous song
# Press 'v' to set volume
# Press 'e' to exit
# >>> r
# Press 'p' to pause
# Press 'r' to resume
# Press 'n' for next song
# Press 'p' for previous song
# Press 'v' to set volume
# Press 'e' to exit
# >>> n
# Press 'p' to pause
# Press 'r' to resume
# Press 'n' for next song
# Press 'p' for previous song
# Press 'v' to set volume
# Press 'e' to exit
# >>> p
# Press 'p' to pause
# Press 'r' to resume
# Press 'n' for next song
# Press 'p' for previous song
# Press 'v' to set volume
# Press 'e' to exit
# >>> p
# Press 'p' to pause
# Press 'r' to resume
# Press 'n' for next song
# ...

# %% [markdown]
# ## list of songs with shuffle

# %%
from pygame import mixer
import random

def play_song(song_list, index):
    mixer.music.load(song_list[index])
    mixer.music.play()

def shuffle_playlist(song_list):
    shuffled_list = song_list.copy()
    random.shuffle(shuffled_list)
    return shuffled_list

def main():
    mixer.init()

    song_list = ["Gulabo.mp3", "Anveshna.mp3", "IkKudi.mp3","Maharani.mp3"]  # Add your song filenames here
    shuffled_list = shuffle_playlist(song_list)
    current_song_index = 0
    play_song(shuffled_list, current_song_index)

    while True:
        print("Press 'p' to pause")
        print("Press 'r' to resume")
        print("Press 'n' for next song")
        print("Press 'p' for previous song")
        print("Press 's' to shuffle playlist")
        print("Press 'v' to set volume")
        print("Press 'e' to exit")

        ch = input(">>> ")

        if ch == "p":
            mixer.music.pause()
        elif ch == "r":
            mixer.music.unpause()
        elif ch == "n":
            current_song_index = (current_song_index + 1) % len(shuffled_list)
            mixer.music.stop()
            play_song(shuffled_list, current_song_index)
        elif ch == "b":
            current_song_index = (current_song_index - 1) % len(shuffled_list)
            mixer.music.stop()
            play_song(shuffled_list, current_song_index)
        elif ch == "s":
            shuffled_list = shuffle_playlist(song_list)
            current_song_index = 0
            mixer.music.stop()
            play_song(shuffled_list, current_song_index)
        elif ch == "v":
            v = float(input("Enter volume (0 to 1): "))
            mixer.music.set_volume(v)
        elif ch == "e":
            mixer.music.stop()
            break

    mixer.quit()

if __name__ == "__main__":
    main()
# Out:
# Press 'p' to pause
# Press 'r' to resume
# Press 'n' for next song
# Press 'p' for previous song
# Press 's' to shuffle playlist
# Press 'v' to set volume
# Press 'e' to exit
# >>> s
# Press 'p' to pause
# Press 'r' to resume
# Press 'n' for next song
# Press 'p' for previous song
# Press 's' to shuffle playlist
# Press 'v' to set volume
# Press 'e' to exit
# >>> n
# Press 'p' to pause
# Press 'r' to resume
# Press 'n' for next song
# Press 'p' for previous song
# Press 's' to shuffle playlist
# Press 'v' to set volume
# Press 'e' to exit
# >>> n
# Press 'p' to pause
# Press 'r' to resume
# Press 'n' for next song
# Press 'p' for previous song
# Press 's' to shuffle playlist
# Press 'v' to set volume
# Press 'e' to exit
# >>> n
# Press 'p' to pause
# Press 'r' to resume
# Press 'n' for next song
# Press 'p' for previous song
# Press 's' to shuffle playlist
# Press 'v' to set volume
# Press 'e' to exit
# >>> n
# Press 'p' to pause
# Press 'r' to resume
# Press 'n' for next song
# ...

# %% [markdown]
# ## With GUI

# %%
import tkinter as tk
from pygame import mixer
import random

def play_song(song_list, index):
    mixer.music.load(song_list[index])
    mixer.music.play()

def shuffle_playlist(song_list):
    shuffled_list = song_list.copy()
    random.shuffle(shuffled_list)
    return shuffled_list

def play_button_callback():
    global is_playing
    if not is_playing:
        is_playing = True
        play_button.config(text="Pause")
        play_song(shuffled_list, current_song_index)
    else:
        is_playing = False
        play_button.config(text="Play")
        mixer.music.pause()

def next_button_callback():
    global current_song_index
    current_song_index = (current_song_index + 1) % len(shuffled_list)
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)

def shuffle_button_callback():
    global shuffled_list, current_song_index
    shuffled_list = shuffle_playlist(song_list)
    current_song_index = 0
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)

mixer.init()

song_list = ["Gulabo.mp3", "Anveshna.mp3", "IkKudi.mp3","Maharani.mp3"]  # Add your song filenames here
shuffled_list = shuffle_playlist(song_list)
current_song_index = 0
is_playing = False

root = tk.Tk()
root.title("My mp3")

play_button = tk.Button(root, text="Play", command=play_button_callback)
next_button = tk.Button(root, text="Next", command=next_button_callback)
shuffle_button = tk.Button(root, text="Shuffle", command=shuffle_button_callback)

play_button.pack()
next_button.pack()
shuffle_button.pack()

root.mainloop()

mixer.quit()

# %% [markdown]
# ## with add songs features

# %%
import tkinter as tk
from pygame import mixer
import random
from tkinter import filedialog

def play_song(song_list, index):
    mixer.music.load(song_list[index])
    mixer.music.play()

def shuffle_playlist(song_list):
    shuffled_list = song_list.copy()
    random.shuffle(shuffled_list)
    return shuffled_list

def play_button_callback():
    global is_playing
    if not is_playing:
        is_playing = True
        play_button.config(text="Pause")
        play_song(shuffled_list, current_song_index)
    else:
        is_playing = False
        play_button.config(text="Play")
        mixer.music.pause()

def next_button_callback():
    global current_song_index
    current_song_index = (current_song_index + 1) % len(shuffled_list)
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)

def shuffle_button_callback():
    global shuffled_list, current_song_index
    shuffled_list = shuffle_playlist(song_list)
    current_song_index = 0
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)

def add_song_button_callback():
    file_path = filedialog.askopenfilename(filetypes=[("Audio Files", "*.mp3")])
    if file_path:
        song_list.append(file_path)
        listbox.insert(tk.END, file_path)

mixer.init()

song_list = ["song1.mp3", "song2.mp3", "song3.mp3"]  # Default song filenames
shuffled_list = shuffle_playlist(song_list)
current_song_index = 0
is_playing = False

root = tk.Tk()
root.title("Music Player")

play_button = tk.Button(root, text="Play", command=play_button_callback)
next_button = tk.Button(root, text="Next", command=next_button_callback)
shuffle_button = tk.Button(root, text="Shuffle", command=shuffle_button_callback)
add_song_button = tk.Button(root, text="Add Song", command=add_song_button_callback)

play_button.pack()
next_button.pack()
shuffle_button.pack()
add_song_button.pack()

listbox = tk.Listbox(root)
for song in song_list:
    listbox.insert(tk.END, song)
listbox.pack()

root.mainloop()

mixer.quit()

# %% [markdown]
# ## with add songs features revised

# %%
import tkinter as tk
from tkinter import filedialog
from pygame import mixer
import random
import os

def play_song(song_list, index):
    mixer.music.load(song_list[index])
    mixer.music.play()

def shuffle_playlist(song_list):
    shuffled_list = song_list.copy()
    random.shuffle(shuffled_list)
    return shuffled_list

def play_button_callback():
    global is_playing
    if not is_playing:
        is_playing = True
        play_button.config(text="Pause")
        play_song(shuffled_list, current_song_index)
    else:
        is_playing = False
        play_button.config(text="Play")
        mixer.music.pause()

def next_button_callback():
    global current_song_index
    current_song_index = (current_song_index + 1) % len(shuffled_list)
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)

def shuffle_button_callback():
    global shuffled_list, current_song_index
    shuffled_list = shuffle_playlist(song_list)
    current_song_index = 0
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)

def add_song_button_callback():
    file_path = filedialog.askopenfilename(filetypes=[("MP3 Files", "*.mp3")])
    if file_path:
        song_list.append(file_path)
        shuffled_list = shuffle_playlist(song_list)
        current_song_index = len(shuffled_list) - 1  # Play the newly added song
        mixer.music.stop()
        play_song(shuffled_list, current_song_index)

mixer.init()

song_list = []  # Initialize with an empty list
shuffled_list = []
current_song_index = 0
is_playing = False

root = tk.Tk()
root.title("Music Player")

play_button = tk.Button(root, text="Play", command=play_button_callback)
next_button = tk.Button(root, text="Next", command=next_button_callback)
shuffle_button = tk.Button(root, text="Shuffle", command=shuffle_button_callback)
add_song_button = tk.Button(root, text="Add Song", command=add_song_button_callback)

play_button.pack()
next_button.pack()
shuffle_button.pack()
add_song_button.pack()

root.mainloop()

mixer.quit()

# %% [markdown]
# ###

# %%
import tkinter as tk
from tkinter import filedialog
from pygame import mixer
import random
import os

def play_song(song_list, index):
    mixer.music.load(song_list[index])
    mixer.music.play()

def shuffle_playlist(song_list):
    shuffled_list = song_list.copy()
    random.shuffle(shuffled_list)
    return shuffled_list

def play_button_callback():
    global is_playing
    if not is_playing:
        is_playing = True
        play_button.config(text="Pause")
        play_song(shuffled_list, current_song_index)
    else:
        is_playing = False
        play_button.config(text="Play")
        mixer.music.pause()

def next_button_callback():
    global current_song_index
    current_song_index = (current_song_index + 1) % len(shuffled_list)
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)

def shuffle_button_callback():
    global shuffled_list, current_song_index
    shuffled_list = shuffle_playlist(song_list)
    current_song_index = 0
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)

def add_songs_button_callback():
    file_paths = filedialog.askopenfilenames(filetypes=[("MP3 Files", "*.mp3")])
    if file_paths:
        for file_path in file_paths:
            song_list.append(file_path)
        shuffled_list = shuffle_playlist(song_list)
        current_song_index = len(shuffled_list) - len(file_paths)  # Play the first newly added song
        mixer.music.stop()
        play_song(shuffled_list, current_song_index)

mixer.init()

song_list = []  # Initialize with an empty list
shuffled_list = []
current_song_index = 0
is_playing = False

root = tk.Tk()
root.title("Music Player")

play_button = tk.Button(root, text="Play", command=play_button_callback)
next_button = tk.Button(root, text="Next", command=next_button_callback)
shuffle_button = tk.Button(root, text="Shuffle", command=shuffle_button_callback)
add_songs_button = tk.Button(root, text="Add Songs", command=add_songs_button_callback)

play_button.pack()
next_button.pack()
shuffle_button.pack()
add_songs_button.pack()

root.mainloop()

mixer.quit()

# %% [markdown]
# ## GUI mp3 player with play pause resume etc

# %%
import tkinter as tk
from tkinter import filedialog
from pygame import mixer
import random
import os

def play_song(song_list, index):
    mixer.music.load(song_list[index])
    mixer.music.play()

def shuffle_playlist(song_list):
    shuffled_list = song_list.copy()
    random.shuffle(shuffled_list)
    return shuffled_list

def play_button_callback():
    global is_playing
    if not is_playing:
        is_playing = True
        play_button.config(text="Pause")
        play_song(shuffled_list, current_song_index)
    else:
        is_playing = False
        play_button.config(text="Play")
        mixer.music.pause()

def next_button_callback():
    global current_song_index
    current_song_index = (current_song_index + 1) % len(shuffled_list)
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)

def shuffle_button_callback():
    global shuffled_list, current_song_index
    shuffled_list = shuffle_playlist(song_list)
    current_song_index = 0
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)

def add_songs_button_callback():
    file_paths = filedialog.askopenfilenames(filetypes=[("MP3 Files", "*.mp3")])
    if file_paths:
        for file_path in file_paths:
            song_list.append(file_path)
        shuffled_list = shuffle_playlist(song_list)
        current_song_index = len(shuffled_list) - len(file_paths)  # Play the first newly added song
        mixer.music.stop()
        play_song(shuffled_list, current_song_index)

def set_volume(volume):
    mixer.music.set_volume(volume / 100)

def volume_scale_callback(event):
    volume = volume_scale.get()
    set_volume(volume)

mixer.init()

song_list = []  # Initialize with an empty list
shuffled_list = []
current_song_index = 0
is_playing = False

root = tk.Tk()
root.title("Music Player")

play_button = tk.Button(root, text="Play", command=play_button_callback)
next_button = tk.Button(root, text="Next", command=next_button_callback)
shuffle_button = tk.Button(root, text="Shuffle", command=shuffle_button_callback)
add_songs_button = tk.Button(root, text="Add Songs", command=add_songs_button_callback)

volume_label = tk.Label(root, text="Volume:")
volume_scale = tk.Scale(root, from_=0, to=100, orient="horizontal", command=volume_scale_callback)

play_button.pack()
next_button.pack()
shuffle_button.pack()
add_songs_button.pack()

volume_label.pack()
volume_scale.pack()

root.mainloop()

mixer.quit()

# %%
import tkinter as tk
from tkinter import filedialog
from pygame import mixer
import random
import os

def play_song(song_list, index):
    mixer.music.load(song_list[index])
    mixer.music.play()

def shuffle_playlist(song_list):
    shuffled_list = song_list.copy()
    random.shuffle(shuffled_list)
    return shuffled_list

def play_button_callback():
    global is_playing
    if not is_playing:
        is_playing = True
        play_button.config(text="Pause")
        play_song(shuffled_list, current_song_index)
        status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))
    else:
        is_playing = False
        play_button.config(text="Play")
        mixer.music.pause()
        status_label.config(text="Paused")

def next_button_callback():
    global current_song_index
    current_song_index = (current_song_index + 1) % len(shuffled_list)
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)
    status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))

def shuffle_button_callback():
    global shuffled_list, current_song_index
    shuffled_list = shuffle_playlist(song_list)
    current_song_index = 0
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)
    status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))

def add_songs_button_callback():
    file_paths = filedialog.askopenfilenames(filetypes=[("MP3 Files", "*.mp3")])
    if file_paths:
        for file_path in file_paths:
            song_list.append(file_path)
        shuffled_list = shuffle_playlist(song_list)
        current_song_index = len(shuffled_list) - len(file_paths)  # Play the first newly added song
        mixer.music.stop()
        play_song(shuffled_list, current_song_index)
        status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))

def set_volume(volume):
    mixer.music.set_volume(volume / 100)

def volume_scale_callback(event):
    volume = volume_scale.get()
    set_volume(volume)

mixer.init()

song_list = []  # Initialize with an empty list
shuffled_list = []
current_song_index = 0
is_playing = False

root = tk.Tk()
root.title("Music Player")

title_label = tk.Label(root, text="Simple Music Player", font=("Helvetica", 16, "bold"))
play_button = tk.Button(root, text="Play", command=play_button_callback)
next_button = tk.Button(root, text="Next", command=next_button_callback)
shuffle_button = tk.Button(root, text="Shuffle", command=shuffle_button_callback)
add_songs_button = tk.Button(root, text="Add Songs", command=add_songs_button_callback)

volume_label = tk.Label(root, text="Volume:")
volume_scale = tk.Scale(root, from_=0, to=100, orient="horizontal", command=volume_scale_callback)

status_label = tk.Label(root, text="No song playing", pady=10)

title_label.pack()
play_button.pack()
next_button.pack()
shuffle_button.pack()
add_songs_button.pack()

volume_label.pack()
volume_scale.pack()

status_label.pack()

root.mainloop()

mixer.quit()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Ideapad\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\Ideapad\AppData\Local\Temp\ipykernel_16036\4279518757.py", line 31, in next_button_callback
#     current_song_index = (current_song_index + 1) % len(shuffled_list)
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# ## without automatically playing songs

# %%
import tkinter as tk
from tkinter import filedialog
from pygame import mixer
import random
import os

def play_song(song_list, index):
    mixer.music.load(song_list[index])
    mixer.music.play()

def shuffle_playlist(song_list):
    shuffled_list = song_list.copy()
    random.shuffle(shuffled_list)
    return shuffled_list

def play_button_callback():
    global is_playing
    if not is_playing:
        is_playing = True
        play_button.config(text="Pause")
        play_song(shuffled_list, current_song_index)
        status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))
    else:
        is_playing = False
        play_button.config(text="Play")
        mixer.music.pause()
        status_label.config(text="Paused")

def next_button_callback():
    global current_song_index
    current_song_index = (current_song_index + 1) % len(shuffled_list)
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)
    status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))

def shuffle_button_callback():
    global shuffled_list, current_song_index
    shuffled_list = shuffle_playlist(song_list)
    current_song_index = 0
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)
    status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))

def add_songs_button_callback():
    file_paths = filedialog.askopenfilenames(filetypes=[("MP3 Files", "*.mp3")])
    if file_paths:
        for file_path in file_paths:
            song_list.append(file_path)
        shuffled_list = shuffle_playlist(song_list)
        current_song_index = len(shuffled_list) - len(file_paths)  # Set the current index without playing
        status_label.config(text="Songs added, select to play")
        
def set_volume(volume):
    mixer.music.set_volume(volume / 100)

def volume_scale_callback(event):
    volume = volume_scale.get()
    set_volume(volume)

mixer.init()

song_list = []  # Initialize with an empty list
shuffled_list = []
current_song_index = 0
is_playing = False

root = tk.Tk()
root.title("Music Player")

title_label = tk.Label(root, text="Simple Music Player", font=("Helvetica", 16, "bold"))
play_button = tk.Button(root, text="Play", command=play_button_callback)
next_button = tk.Button(root, text="Next", command=next_button_callback)
shuffle_button = tk.Button(root, text="Shuffle", command=shuffle_button_callback)
add_songs_button = tk.Button(root, text="Add Songs", command=add_songs_button_callback)

volume_label = tk.Label(root, text="Volume:")
volume_scale = tk.Scale(root, from_=0, to=100, orient="horizontal", command=volume_scale_callback)

status_label = tk.Label(root, text="No song playing", pady=10)

title_label.pack()
play_button.pack()
next_button.pack()
shuffle_button.pack()
add_songs_button.pack()

volume_label.pack()
volume_scale.pack()

status_label.pack()

root.mainloop()

mixer.quit()

# %% [markdown]
# ## GUI Mp3 with list of songs

# %%
import tkinter as tk
from tkinter import filedialog
from pygame import mixer
import random
import os

def play_song(song_list, index):
    mixer.music.load(song_list[index])
    mixer.music.play()

def shuffle_playlist(song_list):
    shuffled_list = song_list.copy()
    random.shuffle(shuffled_list)
    return shuffled_list

def play_button_callback():
    global is_playing
    if not is_playing:
        is_playing = True
        play_button.config(text="Pause")
        play_song(shuffled_list, current_song_index)
        status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))
    else:
        is_playing = False
        play_button.config(text="Play")
        mixer.music.pause()
        status_label.config(text="Paused")

def next_button_callback():
    global current_song_index
    current_song_index = (current_song_index + 1) % len(shuffled_list)
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)
    status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))

def shuffle_button_callback():
    global shuffled_list, current_song_index
    shuffled_list = shuffle_playlist(song_list)
    current_song_index = 0
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)
    status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))

def add_songs_button_callback():
    file_paths = filedialog.askopenfilenames(filetypes=[("MP3 Files", "*.mp3")])
    if file_paths:
        for file_path in file_paths:
            song_list.append(file_path)
        shuffled_list = shuffle_playlist(song_list)
        current_song_index = len(shuffled_list) - len(file_paths)  # Set the current index without playing
        status_label.config(text="Songs added, select to play")
        update_song_list_label()

def update_song_list_label():
    song_list_text.set("\n".join([os.path.basename(song) for song in song_list]))

def set_volume(volume):
    mixer.music.set_volume(volume / 100)

def volume_scale_callback(event):
    volume = volume_scale.get()
    set_volume(volume)

mixer.init()

song_list = []  # Initialize with an empty list
shuffled_list = []
current_song_index = 0
is_playing = False

root = tk.Tk()
root.title("Music Player")

title_label = tk.Label(root, text="Simple Music Player", font=("Helvetica", 16, "bold"))
play_button = tk.Button(root, text="Play", command=play_button_callback)
next_button = tk.Button(root, text="Next", command=next_button_callback)
shuffle_button = tk.Button(root, text="Shuffle", command=shuffle_button_callback)
add_songs_button = tk.Button(root, text="Add Songs", command=add_songs_button_callback)

volume_label = tk.Label(root, text="Volume:")
volume_scale = tk.Scale(root, from_=0, to=100, orient="horizontal", command=volume_scale_callback)

status_label = tk.Label(root, text="No song playing", pady=10)

song_list_label = tk.Label(root, text="Song List:")
song_list_text = tk.StringVar()
song_list_label_display = tk.Label(root, textvariable=song_list_text, anchor="w", justify="left")

title_label.pack()
play_button.pack()
next_button.pack()
shuffle_button.pack()
add_songs_button.pack()

volume_label.pack()
volume_scale.pack()

status_label.pack()

song_list_label.pack()
song_list_label_display.pack()

root.mainloop()

mixer.quit()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Ideapad\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\Ideapad\AppData\Local\Temp\ipykernel_16036\1399009667.py", line 21, in play_button_callback
#     play_song(shuffled_list, current_song_index)
#   File "C:\Users\Ideapad\AppData\Local\Temp\ipykernel_16036\1399009667.py", line 8, in play_song
#     mixer.music.load(song_list[index])
# IndexError: list index out of range
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Ideapad\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\Ideapad\AppData\Local\Temp\ipykernel_16036\1399009667.py", line 21, in play_button_callback
#     play_song(shuffled_list, current_song_index)
#   File "C:\Users\Ideapad\AppData\Local\Temp\ipykernel_16036\1399009667.py", line 8, in play_song
# ...

# %% [markdown]
# ## GUI with shuffled list

# %%
import tkinter as tk
from tkinter import filedialog
from pygame import mixer
import random
import os

def play_song(song_list, index):
    mixer.music.load(song_list[index])
    mixer.music.play()

def shuffle_playlist(song_list):
    shuffled_list = song_list.copy()
    random.shuffle(shuffled_list)
    return shuffled_list

def play_button_callback():
    global is_playing
    if not is_playing:
        is_playing = True
        play_button.config(text="Pause")
        play_song(shuffled_list, current_song_index)
        status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))
    else:
        is_playing = False
        play_button.config(text="Play")
        mixer.music.pause()
        status_label.config(text="Paused")

def next_button_callback():
    global current_song_index
    current_song_index = (current_song_index + 1) % len(shuffled_list)
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)
    status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))

def shuffle_button_callback():
    global shuffled_list, current_song_index
    shuffled_list = shuffle_playlist(song_list)
    current_song_index = 0
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)
    status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))
    update_listbox()

def add_songs_button_callback():
    file_paths = filedialog.askopenfilenames(filetypes=[("MP3 Files", "*.mp3")])
    if file_paths:
        for file_path in file_paths:
            song_list.append(file_path)
        shuffled_list = shuffle_playlist(song_list)
        current_song_index = len(shuffled_list) - len(file_paths)  # Set the current index without playing
        status_label.config(text="Songs added, select to play")
        update_listbox()

def update_listbox():
    song_listbox.delete(0, tk.END)
    for song in song_list:
        song_listbox.insert(tk.END, os.path.basename(song))

    shuffled_listbox.delete(0, tk.END)
    for song in shuffled_list:
        shuffled_listbox.insert(tk.END, os.path.basename(song))

def set_volume(volume):
    mixer.music.set_volume(volume / 100)

def volume_scale_callback(event):
    volume = volume_scale.get()
    set_volume(volume)

mixer.init()

song_list = []  # Initialize with an empty list
shuffled_list = []
current_song_index = 0
is_playing = False

root = tk.Tk()
root.title("Music Player")

title_label = tk.Label(root, text="Simple Music Player", font=("Helvetica", 16, "bold"))
play_button = tk.Button(root, text="Play", command=play_button_callback)
next_button = tk.Button(root, text="Next", command=next_button_callback)
shuffle_button = tk.Button(root, text="Shuffle", command=shuffle_button_callback)
add_songs_button = tk.Button(root, text="Add Songs", command=add_songs_button_callback)

volume_label = tk.Label(root, text="Volume:")
volume_scale = tk.Scale(root, from_=0, to=100, orient="horizontal", command=volume_scale_callback)

status_label = tk.Label(root, text="No song playing", pady=10)

listbox_frame = tk.Frame(root)
song_list_label = tk.Label(listbox_frame, text="Original Song List:")
song_listbox = tk.Listbox(listbox_frame, selectmode=tk.SINGLE)
shuffled_list_label = tk.Label(listbox_frame, text="Shuffled Song List:")
shuffled_listbox = tk.Listbox(listbox_frame, selectmode=tk.SINGLE)

title_label.pack()
play_button.pack()
next_button.pack()
shuffle_button.pack()
add_songs_button.pack()

volume_label.pack()
volume_scale.pack()

status_label.pack()

listbox_frame.pack()
song_list_label.pack()
song_listbox.pack(side=tk.LEFT, padx=10)
shuffled_list_label.pack()
shuffled_listbox.pack(side=tk.RIGHT, padx=10)

update_listbox()

root.mainloop()

mixer.quit()

# %% [markdown]
# ## MP3 Gui with new volume

# %%
import tkinter as tk
from tkinter import filedialog
from pygame import mixer
import random
import os

def play_song(song_list, index):
    mixer.music.load(song_list[index])
    mixer.music.play()

def shuffle_playlist(song_list):
    shuffled_list = song_list.copy()
    random.shuffle(shuffled_list)
    return shuffled_list

def play_button_callback():
    global is_playing
    if not is_playing:
        is_playing = True
        play_button.config(text="Pause")
        play_song(shuffled_list, current_song_index)
        status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))
    else:
        is_playing = False
        play_button.config(text="Play")
        mixer.music.pause()
        status_label.config(text="Paused")

def next_button_callback():
    global current_song_index
    current_song_index = (current_song_index + 1) % len(shuffled_list)
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)
    status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))

def shuffle_button_callback():
    global shuffled_list, current_song_index
    shuffled_list = shuffle_playlist(song_list)
    current_song_index = 0
    mixer.music.stop()
    play_song(shuffled_list, current_song_index)
    status_label.config(text="Now Playing: " + os.path.basename(shuffled_list[current_song_index]))
    update_listbox()

def add_songs_button_callback():
    file_paths = filedialog.askopenfilenames(filetypes=[("MP3 Files", "*.mp3")])
    if file_paths:
        for file_path in file_paths:
            song_list.append(file_path)
        shuffled_list = shuffle_playlist(song_list)
        current_song_index = len(shuffled_list) - len(file_paths)  # Set the current index without playing
        status_label.config(text="Songs added, select to play")
        update_listbox()

def set_volume(volume):
    mixer.music.set_volume(volume / 100)

def decrease_volume_callback():
    volume = mixer.music.get_volume() * 100
    volume = max(0, volume - 10)
    set_volume(volume)

def increase_volume_callback():
    volume = mixer.music.get_volume() * 100
    volume = min(100, volume + 10)
    set_volume(volume)

mixer.init()

song_list = []  # Initialize with an empty list
shuffled_list = []
current_song_index = 0
is_playing = False

root = tk.Tk()
root.title("Music Player")

title_label = tk.Label(root, text="Simple Music Player", font=("Helvetica", 16, "bold"))
play_button = tk.Button(root, text="Play", command=play_button_callback)
next_button = tk.Button(root, text="Next", command=next_button_callback)
shuffle_button = tk.Button(root, text="Shuffle", command=shuffle_button_callback)
add_songs_button = tk.Button(root, text="Add Songs", command=add_songs_button_callback)
decrease_volume_button = tk.Button(root, text="Volume -", command=decrease_volume_callback)
increase_volume_button = tk.Button(root, text="Volume +", command=increase_volume_callback)

status_label = tk.Label(root, text="No song playing", pady=10)

listbox_frame = tk.Frame(root)
song_list_label = tk.Label(listbox_frame, text="Original Song List:")
song_listbox = tk.Listbox(listbox_frame, selectmode=tk.SINGLE)
shuffled_list_label = tk.Label(listbox_frame, text="Shuffled Song List:")
shuffled_listbox = tk.Listbox(listbox_frame, selectmode=tk.SINGLE)

title_label.pack()
play_button.pack()
next_button.pack()
shuffle_button.pack()
add_songs_button.pack()
decrease_volume_button.pack()
increase_volume_button.pack()

status_label.pack()

listbox_frame.pack()
song_list_label.pack()
song_listbox.pack(side=tk.LEFT, padx=10)
shuffled_list_label.pack()
shuffled_listbox.pack(side=tk.RIGHT, padx=10)

update_listbox()

root.mainloop()

mixer.quit()
